# %% [markdown]
# # **WEATHER DATA ANALYSIS**

# %% [markdown]
# ## **To analyse weather data using python and its libraries**
#
# by Aishwarya

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# Importing data from csv file and displaying the dataset.

# %%
data= pd.read_csv("file.csv")

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %% [markdown]
# Having a look at the columns of the dataset

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data['Weather'].nunique()
# Out:
# 50

# %% [markdown]
# #### The cell above shows the number of unique values in Weather column while the cell below shoes the number of unique values observed in each column of the dataframe.

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# #### To check whether there are any missing values. Here if the sum is zero then there are no missing values in the dataframe.

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# #### Getting the number of rows where the whether is exactly 'Clear'

# %%
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# #### Finding the number of times wind speed was 4 km/hr

# %%
data[data['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# #### Renaming columns

# %%
data.rename(columns={'Weather':'Weather Conditions'}, inplace= True)

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# #### Mean visibility observed

# %%
data['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# #### Standard deviation of Pressure observed

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# #### Variance of Relative Humidity

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# #### Number of instances snow was recorded

# %%
data[data['Weather Conditions']=='Snow'].count()
# Out:
# Date/Time             390
# Temp_C                390
# Dew Point Temp_C      390
# Rel Hum_%             390
# Wind Speed_km/h       390
# Visibility_km         390
# Press_kPa             390
# Weather Conditions    390
# dtype: int64

# %% [markdown]
# #### Instances where snow was either a full or partial match

# %%
data[data['Weather Conditions'].str.contains('Snow')].tail(50)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8680  12/27/2012 16:00    -4.5              -6.2         88               37
# 8681  12/27/2012 17:00    -4.2              -5.9         88               32
# 8682  12/27/2012 18:00    -4.0              -5.7         88               28
# 8683  12/27/2012 19:00    -3.9              -5.6         88               26
# 8684  12/27/2012 20:00    -3.7              -5.3         89               37
# 8685  12/27/2012 21:00    -3.7              -4.8         92               24
# 8686  12/27/2012 22:00    -3.8              -4.6         94               20
# 8687  12/27/2012 23:00    -4.0              -5.6         89               24
# 8688   12/28/2012 0:00    -4.2              -5.7         89               19
# 8689   12/28/2012 1:00    -4.4              -6.6         85               15
# 8690   12/28/2012 2:00    -4.3              -6.3         86               11
# ...

# %% [markdown]
# #### All instances where wind speed is above 24 km/hr and visibility is 25

# %%
data[(data['Wind Speed_km/h']>24) & (data['Visibility_km']==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# #### Mean of each column against different weather categories

# %%
import datetime as dt

# %%
from datetime import timedelta

# %%
#changing date col from strings to date 

data['Date/Time']=pd.to_datetime(data['Date/Time'])

# %%
data.groupby('Weather Conditions').mean()
# Out:
#                                                             Date/Time  \
# Weather Conditions
# Clear                                   2012-06-25 18:03:12.760180992
# Cloudy                                  2012-07-01 16:51:29.583333376
# Drizzle                                 2012-09-17 15:00:00.000000000
# Drizzle,Fog                             2012-06-30 00:44:15.000000000
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00.000000000
# Drizzle,Snow                            2012-12-18 16:30:00.000000000
# Drizzle,Snow,Fog                        2012-12-19 20:56:00.000000000
# Fog                                     2012-06-24 21:08:00.000000000
# Freezing Drizzle                        2012-03-05 23:25:42.857142784
# Freezing Drizzle,Fog                    2012-04-30 06:20:00.000000000
# Freezing Drizzle,Haze                   2012-02-01 12:00:00.000000000
# Freezing Drizzle,Snow                   2012-06-27 12:32:43.636363520
# ...

# %% [markdown]
# #### Max and min values of columns for each type of weather condition

# %%
data.groupby('Weather Conditions').max()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather Conditions
# Clear                                   2012-12-30 20:00:00    32.8
# Cloudy                                  2012-12-31 06:00:00    30.5
# Drizzle                                 2012-12-22 01:00:00    18.8
# Drizzle,Fog                             2012-12-19 10:00:00    19.9
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-19 18:00:00     1.2
# Drizzle,Snow,Fog                        2012-12-22 03:00:00     1.1
# Fog                                     2012-12-29 10:00:00    20.8
# Freezing Drizzle                        2012-12-17 00:00:00    -2.3
# Freezing Drizzle,Fog                    2012-12-10 05:00:00    -0.3
# Freezing Drizzle,Haze                   2012-02-01 13:00:00    -5.0
# Freezing Drizzle,Snow                   2012-12-28 02:00:00    -3.3
# ...

# %%
data.groupby('Weather Conditions').min()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather Conditions
# Clear                                   2012-01-03 19:00:00   -23.3
# Cloudy                                  2012-01-01 17:00:00   -21.4
# Drizzle                                 2012-01-23 21:00:00     1.1
# Drizzle,Fog                             2012-01-23 20:00:00     0.0
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-17 15:00:00     0.9
# Drizzle,Snow,Fog                        2012-12-18 21:00:00     0.3
# Fog                                     2012-01-01 00:00:00   -16.0
# Freezing Drizzle                        2012-01-07 11:00:00    -9.0
# Freezing Drizzle,Fog                    2012-01-01 02:00:00    -6.4
# Freezing Drizzle,Haze                   2012-02-01 11:00:00    -5.8
# Freezing Drizzle,Snow                   2012-01-13 03:00:00    -8.3
# ...

# %% [markdown]
# #### another way to see if there are any missing values using heatmaps

# %%
#yticklabels= False to not show the y labeling i.e the rows

sns.heatmap(data.isnull(), yticklabels= False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Analysing the frequencies of different weathers and plotting a line plot to show the same

# %%
Weather=data['Weather Conditions'].value_counts().reset_index()
Weather.columns=['Weather','Count']
Weather.head(25)
# Out:
#                        Weather  Count
# 0                 Mainly Clear   2106
# 1                Mostly Cloudy   2069
# 2                       Cloudy   1728
# 3                        Clear   1326
# 4                         Snow    390
# 5                         Rain    306
# 6                 Rain Showers    188
# 7                          Fog    150
# 8                     Rain,Fog    116
# 9                  Drizzle,Fog     80
# 10                Snow Showers     60
# 11                     Drizzle     41
# 12                    Snow,Fog     37
# 13           Snow,Blowing Snow     19
# 14                   Rain,Snow     18
# 15  Thunderstorms,Rain Showers     16
# 16                        Haze     16
# 17            Drizzle,Snow,Fog     15
# 18               Freezing Rain     14
# 19       Freezing Drizzle,Snow     11
# 20            Freezing Drizzle      7
# 21            Snow,Ice Pellets      6
# 22        Freezing Drizzle,Fog      6
# 23                   Snow,Haze      5
# ...

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.lineplot(x=Weather['Weather'],y=Weather['Count'],data=Weather,color='darkblue')
# Out:
# <AxesSubplot:xlabel='Weather', ylabel='Count'>

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
plt.title('Weather vs Temperature', weight='bold', fontsize=12)
sns.barplot(x=data['Weather Conditions'],y=data['Temp_C'],ci=None)
# Out:
# <AxesSubplot:title={'center':'Weather vs Temperature'}, xlabel='Weather Conditions', ylabel='Temp_C'>

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
plt.title('Weather vs Pressure')
sns.lineplot(x=data['Weather Conditions'],y=data['Press_kPa'],data=data)
# Out:
# <AxesSubplot:title={'center':'Weather vs Pressure'}, xlabel='Weather Conditions', ylabel='Press_kPa'>

# %%
plt.figure(figsize=(20,20))
sns.jointplot(x=data['Rel Hum_%'],y=data['Temp_C'],color='darkblue')
